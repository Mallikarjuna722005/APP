# %%
pwd
# Out:
# 'C:\\Users\\TEMP.AMRITAMYSORE.023\\Malli'

# %%
try:
    print(x)
except:
    print("An exception occurred")
# Out:
# An exception occurred

# %%
try:
    a=int(input("Enter value to a:"))
    b=int(input("Enter value to b:"))
    print(a/b)
except ZeroDivisionError:
    print("An exception occurred")
# Out:
# Enter value to a: 5
# Enter value to b: 10
# 0.5

# %%
try:
    a=int(input("Enter value to a:"))
    b=int(input("Enter value to b:"))
    print(a/b)
except ValueError:
    print("Please enter a value integer")
except ZeroDivisionError: 
    print("Cant be divisible by Zero")
# Out:
# Enter value to a: 5
# Enter value to b: 15
# 0.3333333333333333

# %%
try:
    print(x)
except NameError:   
    print("Variable x is not defined")
except:
    print("An exception occured")
# Out:
# Variable x is not defined

# %%
try:
    num=int(input("Enter a number:"))
    result=100/num
    print(res)
except(ValueError,NameError,ZeroDivisionError)as error:
    print("Error",error)
# Out:
# Enter a number: 0
# Error division by zero

# %%
try:
    print("Hello")
except:
    print("Error")
else:
    print("Nothing went wrong")
# Out:
# Hello
# Nothing went wrong

# %%
try:
    num=int(input("Enter a number:"))
    result=100/num
except ValueError:
    print("Invalid input")  
except ZeroDivisionError:
    print("Cant be divisible by zero")
else:
    print(result)
# Out:
# Enter a number: 3
# 33.333333333333336

# %%
try:
    f=open("students.txt")
    try:
        f.write("Hello world")
    except:
        print("Invalid input")
    finally:
        f.close()
except:
    print("Something went wrong")
# Out:
# Something went wrong

# %%
age=int(input("Enter age:"))
if age < 0:
    raise ValueError("Age cannot be negative")
print("Age=",age)
# Out:
# Enter age: 20
# Age= 20

# %%
marks=int(input("Enter marks:"))
if marks < 0 or marks > 100:
    raise ValueError("Marks must be between 0 and 100")
print("Marks=",marks)
# Out:
# Enter marks: 80
# Marks= 80

# %%
age=int(input("Enter age:"))
assert age>=18
print("Eligible")
# Out:
# Enter age: 20
# Eligible

# %%
def calculate_average(marks):
    assert len(marks)>0,"Marks list cannot be empty"
    return sum(marks)/len(marks)
marks=[85,90,78,92,68]
print("Average marks:",calculate_average(marks))
# Out:
# Average marks: 82.6

# %%
class InvalidMarksError(Exception):
    pass
marks=int(input("Enter marks:"))
try:
    if marks < 0 or marks > 100:
        raise InvalidMarksError("Marks must be between 0 and 100")
    print("Marks accepted:",marks)
except InvalidMarksError as error:
    print("Error:",error)
# Out:
# Enter marks: 110
# Error: Marks must be between 0 and 100
