# %%
pwd
# Out:
# 'C:\\Users\\TEMP.AMRITAMYSORE.015\\Malli_11'

# %%
#Factorial series
def factorial(n):
    if n==0:
        return 1
    else:
        return n*factorial(n-1)
print("Factorail of 5:",factorial(5))
# Out:
# Factorail of 5: 120

# %%
#Fibonacci series
def fibonacci(n):
    if n <= 1:
        return n
    return fibonacci(n - 1) + fibonacci(n - 2)
n = 7
for i in range(n):
    print(fibonacci(i), end=" ")
# Out:
# 0 1 1 2 3 5 8

# %%
#Sum of n numbers
def sumn(n,num=None):
    if num is None:
        num=[float(input(f"Enter number{i+1}:")) for i in range(n)]
    return sum(num)
n=int(input("Enter n:"))
print(sumn(n))
# Out:
# Enter n: 2
# Enter number1: 2
# Enter number2: 4
# 6.0

# %%
#lambda Function
n=-5
check=lambda x:"Positive" if x>0 else "negative"
print(check(n))
# Out:
# negative

# %%
price=float(input("Enter product price:"))
discount=float(input("Enter discount percentage:"))
final_price=lambda p,d:p-(p*d/100)
print("final price:₹",final_price(price,discount))
# Out:
# Enter product price: 70
# Enter discount percentage: 10
# final price:₹ 63.0

# %%
#Increase every mark by 5 bonus marks
marks=list(map(int,input("Enter marks separated by spaces:").split()))
updated_marks=list(map(lambda x:min(x+5,100),marks))
print("Original Marks:",marks)
print("Updated Marks:",updated_marks)
# Out:
# Enter marks separated by spaces: 20 40 11
# Original Marks: [20, 40, 11]
# Updated Marks: [25, 45, 16]

# %%
# A University provides a scholarship to student who score at least 80 marks
marks=list(map(int,input("Enter student marks:").split()))
eligible=list(filter(lambda mark:mark>=80,marks))
print("All Marks",marks)
print("Scholarship Eligible:",eligible)
# Out:
# Enter student marks: 80 95 77 83
# All Marks [80, 95, 77, 83]
# Scholarship Eligible: [80, 95, 83]

# %%
names = input("Enter student names: ").split()
marks = list(map(int, input("Enter student marks: ").split()))
students = list(zip(names, marks))
eligible = list(filter(lambda student: student[1] >= 80, students))
print("Scholarship Eligible:")
for name, mark in eligible:
    print(name, mark)
# Out:
# Enter student names:  A B C D
# Enter student marks:  80 90 50 85
# Scholarship Eligible:
# A 80
# B 90
# D 85

# %%
# Arranging according to marks in descending order
std=[("A",85),("B",65),("C",95),("D",75)]
std=sorted(std,key=lambda st:st[1],reverse=True)
print("Student sorted by marks")
for st in std:
    print(st)
# Out:
# Student sorted by marks
# ('C', 95)
# ('A', 85)
# ('D', 75)
# ('B', 65)

# %%
#An online store has a list of product prices
#The system must:
#add 18% gst to every product  
#consider only products costing more than 500
from functools import reduce
pr=list(map(float,input("enter price").split()))
prgst=list(map(lambda x: x*1.18,pr))
filteredpr=list(filter(lambda x: x>500,prgst))
t=reduce(lambda x,y: x+y,filteredpr,0)
print("Original prices",pr)
print("Price with gst",prgst)
print("Poducts above 500:",filteredpr)
print("Total:",round(t,2))
# Out:
# enter price 600 4000 700
# Original prices [600.0, 4000.0, 700.0]
# Price with gst [708.0, 4720.0, 826.0]
# Poducts above 500: [708.0, 4720.0, 826.0]
# Total: 6254.0

# %%
def std(*mark):
    total=sum(mark)
    per=total/len(mark)
    if per>=90:
        grade="A+"
    elif per>=80:
        grade="A"
    elif per>=70:
        grade="B+"
    elif per>=60:
        grade="B"
    elif per>=50:
        grade="C"   
    else:
        grade="F"
    print("Total Marks:",t)
    print("Percentage:",per,"%")
    print("Grade:",grade)
std(88,79,90,94.79)
# Out:
# Total Marks: 6254.0
# Percentage: 87.9475 %
# Grade: A
